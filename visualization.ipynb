# %%
from blockulib.playing import PlayingLoop, SimpleLoop, RandomLoop, ModelBasedLoop, Probe, DeepSearch
from blockulib.visual import deep_display

# %%
deep_display(RandomLoop)
# Out:
# Game Length = 17
